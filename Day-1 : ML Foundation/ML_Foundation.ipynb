# %% [markdown]
# # 🔥 **Welcome to Day 1: ML Setup & Essentials**
#
# 👨‍🏫 Today’s Goals:
# - ✅ Understand Google Colab environment
# - ✅ Connect Google Drive for storage
# - ✅ Recap basic Python & math
# - ✅ Learn core libraries: NumPy, Pandas, Matplotlib
# - ✅ Access datasets from GitHub
# - ✅ Use terminal commands & data downloads

# %% [markdown]
# ---
# ## 🚀 **1. Setting Up Google Colab**
#
# 🟢 Google Colab is a cloud-based Python notebook powered by Google.
# 💻 You don’t need to install anything – just a browser.
#
# 💡 **Tip:** You get free access to GPUs and TPUs for ML training!
#
# 🔧 We'll start by checking Python and GPU versions.

# %%
# Check Python version
# !python --version
# Out:
# Python 3.11.12

# %%
# Check GPU availability
import tensorflow as tf
print("GPU Available:", tf.config.list_physical_devices('GPU'))
# Out:
# GPU Available: []

# %%
# A simple print statement
print("Hello Class!")
# Out:
# Hello Class!

# %% [markdown]
# ---
# ## 🧠 **2. Python & Math Recap**
#
# Before we build ML models, let's brush up on:
# - Basic arithmetic
# - Variables and Data Types
# - List, Dict
# - Loops, Conditional statements
# - Basic functions
#
# 📘 Don’t worry if you're rusty — we’ll keep it simple.

# %%
# Basic Arithmetic
a = 5
b = 10
print(f"The sum of {a} and {b} is: {a + b}")
print("The sum of {} and {} is: {}".format(a, b, a + b))
# Out:
# The sum of 5 and 10 is: 15
# The sum of 5 and 10 is: 15

# %%
# Variables and Data Types
name = "Alice"  # String
age = 30      # Integer
height = 5.7  # Float
is_student = False # Boolean
print(f"Name: {name}, Age: {age}, Height: {height}, Is student: {is_student}")
# Out:
# Name: Alice, Age: 30, Height: 5.7, Is student: False

# %%
# Lists
numbers = [1, 2, 3, 4, 5]
print(f"List of numbers: {numbers}")
print(f"First element: {numbers[0]}")
numbers.append(6)
print(f"List after appending: {numbers}")
# Out:
# List of numbers: [1, 2, 3, 4, 5]
# First element: 1
# List after appending: [1, 2, 3, 4, 5, 6]

# %%
# Dictionaries
student = {'name': 'Bob', 'major': 'CS', 'grade': 'A'}
print(f"Student dictionary: {student}")
print(f"Student's name: {student['name']}")
student['city'] = 'New York'
print(f"Student dictionary after adding city: {student}")
# Out:
# Student dictionary: {'name': 'Bob', 'major': 'CS', 'grade': 'A'}
# Student's name: Bob
# Student dictionary after adding city: {'name': 'Bob', 'major': 'CS', 'grade': 'A', 'city': 'New York'}

# %%
# Loops(for)
for number in numbers:
    print(f"Square of {number} is: {number**2}")
# Out:
# Square of 1 is: 1
# Square of 2 is: 4
# Square of 3 is: 9
# Square of 4 is: 16
# Square of 5 is: 25
# Square of 6 is: 36

# %%
# Conditional Statements (if/else)
score = 75
if score >= 70:
    print("Pass")
else:
    print("Fail")
# Out:
# Pass

# %%
# Functions
def greet(person):
    print(f"Hello, {person}!")

greet("GL Bajaj")
# Out:
# Hello, GL Bajaj!

# %%
# Input Function
name = input('What is your name?\n')
print ('Welcome ' + name + ' to the Course on Machine Learning')
# Out:
# What is your name?
# GL Bajaj
# Welcome GL Bajaj to the Course on Machine Learning

# %% [markdown]
# ---
# ## 📂 **3. Mounting Google Drive**
#
# We’ll mount your Google Drive to access files across notebooks.
# You can save and read datasets directly!
#
# 📁 This is useful when dealing with:
# - Dataset storage
# - Saving models
# - Sharing notebooks
#
# 👣 **Steps:**
# 1. Run the mount command.
# 2. Open the link → Sign in

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ---
# ## 📊 **4. Working with ML Libraries**
#
# We’ll explore 3 powerful libraries used in every ML project:
#
# 🔹 **NumPy** - for numerical operations
# 🔹 **Pandas** - for tabular data
# 🔹 **Matplotlib** - for plotting and visualization
#
# 📈 These will help us manipulate and visualize data like a pro.

# %% [markdown]
# ---
# **4.1. NumPy** - NumPy is a general-purpose fundamental package for scientific computing with Python. It contains various features including these important ones:
#
# - Array creation
# - Reshaping array
# - Flatten array
#
# 🔗 Source: Official website of NumPy (https://numpy.org/)

# %%
import numpy as np

# %%
# Creating NumPy arrays
array_1d = np.array([1, 2, 3])
array_2d = np.array([[1, 2], [3, 4]])
print(f"1D NumPy array:\n{array_1d}")
print(f"2D NumPy array:\n{array_2d}", end='\n\n')

# Basic array operations
print(f"Sum of array_1d: {np.sum(array_1d)}")
print(f"Mean of array_2d: {np.mean(array_2d)}")
print(f"Element-wise multiplication:\n{array_1d * 2}")
# Out:
# 1D NumPy array:
# [1 2 3]
# 2D NumPy array:
# [[1 2]
#  [3 4]]
#
# Sum of array_1d: 6
# Mean of array_2d: 2.5
# Element-wise multiplication:
# [2 4 6]

# %%
b1 = np.array([1,2,3,5,5,8])    #Declaring a NumPy Array
b2 = np.array([4,5,6,7,7,9])

print(b1+b2, end='\n\n')

print(b2 * 3, end='\n\n')
print("No. of dimensions: ", b1.ndim, end='\n\n')  # Rows in array, considered as a matrix.
# Printing shape of array
print("Shape of array: ", b1.shape, end='\n\n')  # Dimension

#reshaping an array
r_b1=b1.reshape(2,3)

print("Reshaped array: ", r_b1)
print("Shape of array: ", r_b1.shape, end='\n\n')

# Printing size (total number of elements) of array
print("Size of array: ", b1.size) # elements in a row or column elements.

# Printing the datatype of elements in array
print("Array stores elements of type: ", b1.dtype)
# Out:
# [ 5  7  9 12 12 17]
#
# [12 15 18 21 21 27]
#
# No. of dimensions:  1
#
# Shape of array:  (6,)
#
# Reshaped array:  [[1 2 3]
#  [5 5 8]]
# Shape of array:  (2, 3)
#
# Size of array:  6
# Array stores elements of type:  int64

# %% [markdown]
# ---
# **4.2 Pandas** - Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language.
#
# 🔗 Source: Official website of Pandas (https://pandas.pydata.org/)

# %%
import pandas as pd

# %%
# Creating a Pandas Series
series = pd.Series([10, 20, 30, 40])
print(f"Pandas Series:\n{series}", end='\n\n')
# Out:
# Pandas Series:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
series
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
# Creating a Pandas DataFrame
data = {'Name': ['Alice', 'Bob', 'Charlie'],
        'Age': [25, 30, 28],
        'City': ['New York', 'London', 'Paris']}
df = pd.DataFrame(data)
print(f"Pandas DataFrame:\n{df}")
# Out:
# Pandas DataFrame:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30    London
# 2  Charlie   28     Paris

# %%
df
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30    London
# 2  Charlie   28     Paris

# %% [markdown]
# ---
# **4.3 Matplotlib** - Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible.
#
# - Create publication quality plots.
# - Make interactive figures that can zoom, pan, update.
# - Customize visual style and layout.
# - Export to many file formats.
# - Embed in JupyterLab and Graphical User Interfaces.
# - Use a rich array of third-party packages built on Matplotlib.
#
# 🔗 Source: Official website of Matplotlib (https://matplotlib.org/)

# %%
import matplotlib.pyplot as plt

# %%
# Simple line plot
x = np.array([1, 2, 3, 4, 5])
y = x**2
plt.plot(x, y)
plt.show()

# %%
# Simple bar chart
cities = ['New York', 'London', 'Paris']
populations = [8.4, 9.0, 2.1]
plt.bar(cities, populations)
plt.xlabel("City")
plt.ylabel("Population (in millions)")
plt.title("City Populations")
plt.show()

# %%
# Plotting image
import matplotlib.image as mpimg
img = mpimg.imread("/content/drive/MyDrive/python.jpg")
plt.imshow(img)

# %% [markdown]
# ---
# ## 🧪 **5. Terminal Commands & File Access**
#
# Use `!` in Colab to run shell commands like:
#
# - `!ls` – list files
# - `!pip install` – install packages
# - `!wget` – download from the internet
#
# 🔄 Combine this with Drive or GitHub for powerful workflows!

# %%
# !ls
# Out:
# drive  hello.txt  sample_data

# %%
# !echo "Hello" >> hello.txt

# %%
# !wget
# Out:
# wget: missing URL
# Usage: wget [OPTION]... [URL]...
#
# Try `wget --help' for more options.

# %% [markdown]
# ---
# ## 🌐 **6. Cloning GitHub Repositories**
#
# GitHub hosts countless public datasets and projects.
#
# 📦 Today, we’ll clone a dataset repo using:
#
# `!git clone <repo-url>`

# %%
# !git clone https://github.com/datasciencedojo/datasets
# Out:
# Cloning into 'datasets'...
# remote: Enumerating objects: 79, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 79 (delta 2), reused 2 (delta 2), pack-reused 75 (from 1)
# Receiving objects: 100% (79/79), 17.97 MiB | 16.18 MiB/s, done.
# Resolving deltas: 100% (35/35), done.

# %%
# !ls datasets
# Out:
# 'Data Exploration Visulization and feature engineering using R.pdf'   slideSourceFile.Rmd
#  README.md							      titanic.csv
#  rmarkdownd_template.Rmd					      wine.rda
#  slides.html							      WorldDBTables

# %% [markdown]
# ---
# ## 📈 **7. Read CSV & Show Data**
#
# We’ll use Pandas to load a `.csv` dataset and preview it.
#
# 📌 Useful functions:
# - `df.head()`
# - `df.describe()`
# - `df.info()`
#
# Let’s look at rows, columns, nulls, and more.

# %%
import pandas as pd
df = pd.read_csv('/content/datasets/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ---
# ## 📚 End of Day 1 Recap & Homework
#
# 🎉 Today you learned:
# - Setting up Colab & Drive
# - Using NumPy, Pandas, Matplotlib
# - Accessing GitHub datasets
# - Terminal tricks like `wget`
#
# 🧠 **Mini Task:**
# - Choose any `.csv` from GitHub
# - Load it, perform basic EDA, and visualize one chart
#
# 📤https://github.com/absingh22/ML-Workshop
#
#
# ---
